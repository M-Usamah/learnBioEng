# %%
# %pip install -qU pydicom
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pydicom

# %% [markdown]
# ## How to read Dicom file

# %%
dicom_file = pydicom.dcmread("/media/usamah/84a2f44c-6dd1-4271-ad93-7d9facc4eec4/projects/lumbar/datasets/Category Wise Seperated Data/1-APRIL-21/MRI LUMBO SACRAL SPINE/248  Amjad  52y/248  amjad  52y/SAVE IMAGE/12_0.dcm_0.dcm_0.dcm")

# %%
dicom_file
# Out:
# Dataset.file_meta -------------------------------
# (0002,0000) File Meta Information Group Length  UL: 190
# (0002,0001) File Meta Information Version       OB: b'\x00\x01'
# (0002,0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002,0003) Media Storage SOP Instance UID      UI: 1.2.392.200036.9123.100.12.11.12298.20210401105039.1.1
# (0002,0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002,0012) Implementation Class UID            UI: 1.2.804.114118.3
# (0002,0013) Implementation Version Name         SH: 'eFilm'
# (0002,0016) Source Application Entity Title     AE: 'AE_TITLE'
# -------------------------------------------------
# (0008,0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'OTHER']
# (0008,0016) SOP Class UID                       UI: MR Image Storage
# (0008,0018) SOP Instance UID                    UI: 1.2.392.200036.9123.100.12.11.12298.20210401105039.1.1
# ...

# %% [markdown]
# ## How to read and custamize the tags
